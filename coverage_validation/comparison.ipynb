# %%
import numpy as np
import pandas as pd

# %%
sort_by = ["dgp", "statistic", "method", "n"]
csv_reference= pd.read_csv("results_uz_es/results_uz_es.csv").sort_values(sort_by)
csv_new = pd.read_csv("results_eh_es/results_eh_es.csv").sort_values(sort_by)

# %%
csv_reference
# Out:
#         method  nominal_1_sided_coverage  nominal_2_sided_coverage  \
# 21      double                     0.975                      0.95
# 25      double                     0.975                      0.95
# 29      double                     0.975                      0.95
# 20  percentile                     0.975                      0.95
# 24  percentile                     0.975                      0.95
# 28  percentile                     0.975                      0.95
# 7       double                     0.975                      0.95
# 9       double                     0.975                      0.95
# 17      double                     0.975                      0.95
# 6   percentile                     0.975                      0.95
# 8   percentile                     0.975                      0.95
# 16  percentile                     0.975                      0.95
# 15      double                     0.975                      0.95
# ...

# %%
csv_new
# Out:
#         method  nominal_1_sided_coverage  nominal_2_sided_coverage  \
# 25      double                     0.975                      0.95
# 27      double                     0.975                      0.95
# 29      double                     0.975                      0.95
# 24  percentile                     0.975                      0.95
# 26  percentile                     0.975                      0.95
# 28  percentile                     0.975                      0.95
# 13      double                     0.975                      0.95
# 15      double                     0.975                      0.95
# 17      double                     0.975                      0.95
# 12  percentile                     0.975                      0.95
# 14  percentile                     0.975                      0.95
# 16  percentile                     0.975                      0.95
# 19      double                     0.975                      0.95
# ...
