# %%
import numpy as np

from bootstrap_diagnostics import DoubleBootstrap

# %%
rng = np.random.default_rng(123)

# %%
mean = 1.0
sample_size = 20
n_covers = 0
n_iterations = 500
seed = 42
confidence_level = 0.95

for i in range(n_iterations):
    sample = rng.exponential(scale=mean, size=sample_size)
    db = DoubleBootstrap(sample, lambda x: np.mean(x))
    ci = db.confidence_interval(confidence_level, seed=seed)

    if ci.lower <= mean <= ci.upper:
        n_covers += 1

    print(f"{i}: {n_covers / (i + 1)}, {ci}")

print(f"Final coverage: {n_covers / n_iterations}")
# Out:
# 0: 1.0
# 1: 1.0
# 2: 1.0
# 3: 1.0
# 4: 1.0
# 5: 1.0
# 6: 1.0
# 7: 1.0
# 8: 1.0
# 9: 1.0
# 10: 1.0
# 11: 1.0
# 12: 1.0
# 13: 1.0
# 14: 1.0
# 15: 1.0
# 16: 1.0
# 17: 1.0
# 18: 1.0
# 19: 1.0
# 20: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       9 sample = rng.exponential(scale=mean, size=sample_size)
#      10 db = DoubleBootstrap(sample, lambda x: np.mean(x))
# ---> 11 ci = db.confidence_interval(confidence_level, seed=seed)
#      13 if ci.lower <= mean <= ci.upper:
#      14     n_covers += 1
#
# File ~/Developer/BSC/bootstrap-diagnostics/src/bootstrap_diagnostics/double_bootstrap.py:128, in DoubleBootstrap.confidence_interval(self, confidence_level, side, B1_resamples, B2_resamples, seed)
#     124     raise ValueError("Number of resamples must be positive")
#     126 rng = np.random.default_rng(seed)
# ...
